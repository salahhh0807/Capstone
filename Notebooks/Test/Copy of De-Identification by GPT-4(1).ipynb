# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install openai
# !pip install tiktoken
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 1.9 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 21.2 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# ...

# %%
import openai
import tiktoken
import os
import time
from bs4 import BeautifulSoup
import pprint
openai.api_key = "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"

# %%
directory = "gdrive/My Drive/"

# %%
# os.listdir(directory)

# %%
def num_tokens_from_string(string: str, encoding_name: str) -> int:
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

# %%
def chatgpt_completion(model_new="gpt-4",prompt_new="hi", temperature_new=0.05, top_p_new=1, n_new=1, max_tokens_new=100):
    Chat_Completion = openai.ChatCompletion.create(
        model=model_new,
        messages=[
            {"role": "user", "content": prompt_new}
        ],
        temperature=temperature_new,
        top_p=top_p_new,
        n=n_new,
        max_tokens=max_tokens_new,
        presence_penalty=0,
        frequency_penalty=0
    )
    return Chat_Completion

# %%
directory = 'gdrive/My Drive/GE Capstone/Data/i2b2/training-PHI-Gold-Set1/'

# %%
list_of_text_contents = []
list_of_files = []

# for filename in os.listdir(directory):
#     f = os.path.join(directory, filename)
#     if os.path.isfile(f):
#         print(os.path.basename(os.path.normpath(f))[:-4])
#         list_of_files.append(os.path.basename(os.path.normpath(f))[:-4])
with open("389-02.xml") as fp:
    soup = BeautifulSoup(fp, features="xml")
    text = soup.find('TEXT')
    text_content = text.contents[0]
    list_of_text_contents.append(text_content)
# print(list_of_text_contents)

for i in range(len(list_of_text_contents)):
    prompt = "Replace private information such as a person's name, date, birthday, gender, location, etc. with #####. Print out the revised text. " + list_of_text_contents[i]

    num_tokens = num_tokens_from_string(prompt, "gpt2")
    print(num_tokens)

    completion = chatgpt_completion(prompt_new=prompt,max_tokens_new=4000)
    rewrite_finding = completion.choices[0].message.content

    # rewrite_file = list_of_files[i] + "_anonymized.txt"

    # with open(rewrite_file, "w") as f:
    #     f.write(rewrite_finding)

    print("-----------The" + str(i + 1) + "个\n-----------")
    print("-----------My prompt " + "\n-----------")
    print(prompt)
    print("-----------Anonymized " + "\n-----------")
    print(rewrite_finding)

    time.sleep(10)
# Out:
# 5292
# -----------The1个
# -----------
# -----------My prompt
# -----------
# Replace private information such as a person's name, date, birthday, gender, location, etc. with #####. Print out the revised text.
#
#
# Record date: 2132-05-27
#
# Date 5/27/32
# Time 4am
# Team E Admission Note
#
# Patient: Pearson, Tyler
# Medical Record Number: 727 19 02
# Room: J8845I
# Date of Admission: 5/26/32
# PCP: Yale Triplett (Turner Clinic)
# Attending Physician: Arias/Wesley
# Admitting Intern: Jaquan Mahoney
# Code Status: FULL CODE
#
# Source: Patient, Medical Record
#
# ID/CC:
# 87yoM h/o COPD, DM2, CVA p/w SOB, cough.
#
# History of Present Illness:
# ...

# %%
import re
print(len(re.findall(r'#####', rewrite_finding)))
# rewrite_finding
# Out:
# 13

# %%
rewrite_finding_tokens = re.split(r'[\s\t\n]+', rewrite_finding)
rewrite_finding_tokens = [x for x in rewrite_finding_tokens if x != '']
original_tokens = re.split(r'[\s\t\n]+', list_of_text_contents[i])
original_tokens = [x for x in original_tokens if x != '']
print(rewrite_finding_tokens)
print(original_tokens)
# Out:
# ['Record', 'date:', '#####', 'Date', '#####', 'Time', '4am', 'Team', 'E', 'Admission', 'Note', 'Patient:', '#####', 'Medical', 'Record', 'Number:', '#####', 'Room:', '#####', 'Date', 'of', 'Admission:', '#####', 'PCP:', '#####', 'Attending', 'Physician:', '#####', 'Admitting', 'Intern:', '#####', 'Code', 'Status:', 'FULL', 'CODE', 'Source:', 'Patient,', 'Medical', 'Record', 'ID/CC:', '87yoM', 'h/o', 'COPD,', 'DM2,', 'CVA', 'p/w', 'SOB,', 'cough.', 'History', 'of', 'Present', 'Illness:', 'Patient', 'w/', 'severe', 'COPD', '(PFT', 'not', 'available).', 'Reports', 'coughing', 'x', '3wks,', 'productive', 'of', 'light,', 'white', 'sputum.', 'Has', 'had', 'intermittent,', 'fluctuating', 'symptoms', 'of', 'cough/DOE', 'since', 'then.', '10d', 'prior,', 'seen', 'at', 'VGH', 'ED', 'and', 'was', 'discharged', 'w/', 'prednisone', '(7d', 'course).', 'He', 'reports', 'that', 'his', 'symptoms', 'never', 'improved', 'on', 'prednisone.', 'At', 'baseline,', 'he', 'is', 'able', 'to', 'walk', '40-50y',
# ...

# %%
print(len(rewrite_finding_tokens))
print(len(original_tokens))
# Out:
# 874
# 884

# %%
set(original_tokens) - set(rewrite_finding_tokens)
# Out:
# {'#84464',
#  '(Turner',
#  '02',
#  '19',
#  '2132-05-27',
#  '5/26/32',
#  '5/27/32',
#  '5/3/32):',
#  '727',
#  'Arias/Wesley',
#  'Clinic)',
#  'J8845I',
#  'Jaquan',
#  'Land',
#  'Mahoney',
#  'Mahoney,',
#  'North',
#  'Pearson,',
#  'Steven',
#  'Triplett',
#  'Tyler',
#  'Wilkesboro',
#  'Yale'}

# %%
set(rewrite_finding_tokens) - set(original_tokens)
# Out:
# {'#####', '#####,', '####):'}

# %%
def evaluation_metrics(original_tokens, tag_list, rewritten_tokens):
  # get all the tag text
  tags = [x["text"] for x in tag_list]

  # tokenize tags
  tags = [re.split(r'[\s\t\n]+', x) for x in tags]
  tags = [item for sublist in tags for item in sublist]
  tags = [x for x in tags if x != '']

  # get unmasked tokens, which should not be masked
  unmasked_tokens = [x for x in original_tokens if x not in tags]

  FN = 0
  FP = 0
  TP = 0
  TN = 0

  for i in range (len(unmasked_tokens)):
    if unmasked_tokens[i] in rewritten_tokens:
      TN += 1
    else:
      FP += 1

  for i in range (len(tags)):
    if tags[i] not in rewritten_tokens:
      TP += 1
    else:
      FN += 1

  accuracy = (TP + TN)/(TP + FP + TN + FN)
  precision = TP/(TP + FP)
  recall = TP/(TP + FN)
  F1_score = 2 * precision * recall /(precision + recall)

  return {"accuracy": accuracy, "precision": precision, "recall": recall, "F1-score": F1_score}

# %%
tag_list = [{'text': '2129-08-20', 'type': 'DATE'}, {'text': 'July 06, 2129', 'type': 'DATE'}, {'text': 'Robert Trejo', 'type': 'DOCTOR'}, {'text': '17 Unicorn Way', 'type': 'STREET'}, {'text': 'Chickasha', 'type': 'CITY'}, {'text': 'NC', 'type': 'STATE'}, {'text': '75156', 'type': 'ZIP'}, {'text': 'Tyler Pearson', 'type': 'PATIENT'}, {'text': 'WMC', 'type': 'HOSPITAL'}, {'text': '727-19-02', 'type': 'MEDICALRECORD'}, {'text': 'Trejo', 'type': 'DOCTOR'}, {'text': 'Tyler Pearson', 'type': 'PATIENT'}, {'text': 'Pearson', 'type': 'PATIENT'}, {'text': 'Steven E. Land', 'type': 'DOCTOR'}, {'text': 'SEL', 'type': 'DOCTOR'}, {'text': 'kerns', 'type': 'DOCTOR'}]
tag_list
# Out:
# [{'text': '2129-08-20', 'type': 'DATE'},
#  {'text': 'July 06, 2129', 'type': 'DATE'},
#  {'text': 'Robert Trejo', 'type': 'DOCTOR'},
#  {'text': '17 Unicorn Way', 'type': 'STREET'},
#  {'text': 'Chickasha', 'type': 'CITY'},
#  {'text': 'NC', 'type': 'STATE'},
#  {'text': '75156', 'type': 'ZIP'},
#  {'text': 'Tyler Pearson', 'type': 'PATIENT'},
#  {'text': 'WMC', 'type': 'HOSPITAL'},
#  {'text': '727-19-02', 'type': 'MEDICALRECORD'},
#  {'text': 'Trejo', 'type': 'DOCTOR'},
#  {'text': 'Tyler Pearson', 'type': 'PATIENT'},
#  {'text': 'Pearson', 'type': 'PATIENT'},
#  {'text': 'Steven E. Land', 'type': 'DOCTOR'},
#  {'text': 'SEL', 'type': 'DOCTOR'},
#  {'text': 'kerns', 'type': 'DOCTOR'}]

# %%
evaluation_metrics(original_tokens, tag_list, rewrite_finding_tokens)
# Out:
# {'accuracy': 0.9768211920529801,
#  'precision': 0.5434782608695652,
#  'recall': 1.0,
#  'F1-score': 0.704225352112676}
